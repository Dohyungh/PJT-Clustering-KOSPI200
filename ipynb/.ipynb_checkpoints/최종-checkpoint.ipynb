# %%
import time
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
# from sklearn_extra.cluster import KMedoids

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.mixture import GaussianMixture

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import estimate_bandwidth
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.cluster import MeanShift
from sklearn.cluster import AgglomerativeClustering
#from konlpy.tag import Komoran

#import pandas_datareader as pdr
from datetime import datetime

from scipy.cluster.hierarchy import linkage 
from scipy.cluster.hierarchy import dendrogram 

from tslearn.clustering import TimeSeriesKMeans
from tslearn.metrics import dtw

import scipy.spatial.distance as ssd

#from gensim.models import Word2Vec as w_to_v

# %%
df = pd.read_csv('../data/df.csv', encoding = 'euc-kr')
df_price = pd.read_pickle('../fkl/price_normal.fkl')
df_dtw_matrix = pd.read_pickle('../fkl/dtw_matrix.fkl')

df_finance = pd.read_pickle('../fkl/financial_i_log_categoric.fkl')
df_price = df_price.dropna(axis = 0)

# %% [markdown]
# # 기업개요

# %%
#TFidf 변환 및 KMeans 학습

countvectorizer = CountVectorizer(stop_words=['1월', '1일','2월','3월','4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월', 'M', 'co', 'company', 'global', 'inc', '가능', '가능', '가치', '각종', 
                                              '감소', '강화', '개', '개선', '개시', '개요', '거점', '결과', '결정', '경영', 
                                              '경우', '경쟁력', '계속', '계획', '공시', '과정', '관련', '관리', '구분', 
                                              '구성', '구조', '구축', '국가', '국내', '국내외', '규모', '극대', '글로벌', 
                                              '기간', '기능', '기대', '기록', '기반', '기업', '기존', '기준', '기초',
                                              '기타', '기회', '내용', '노력', '누적', '능력', '다각', '다수', '다양', '다음',
                                              '단계', '단위', '단일', '달성', '담당', '당기', '당사', '대비', '대상', '대응',
                                              '도약', '도입', '동기', '동력', '동사', '동시', '드', '등', '마련', '매출', 
                                              '매출액', '목적', '목표', '및', '바탕', '반기', '반영', '방식', '법인', '변경',
                                              '변동', '변화', '별도', '보수', '보호', '부가', '부문', '부분', '분기', '분류',
                                              '분야', '비용', '비중', '사업', '사업장', '사용', '사항', '상기', '상반기', 
                                              '상승', '상장', '상호', '상황', '선도', '설계', '설립', '설비', '성격', '성장',
                                              '세계', '소유', '수요', '수익', '수준', '수출', '수행', '시작', '시장', '시행',
                                              '실적', '아래', '안정', '업무', '업체', '역량', '역할', '연간', '연결', '영역', 
                                              '영업', '영위', '영향', '예상', '예정', '완료', '요구', '요약', '요인', '우수', 
                                              '우위', '운영', '위주', '위치', '유가증권', '유지', '의', '이상', '이익', '이하', 
                                              '이후', '일반', '일부', '임대', '입지', '자금', '자본', '자산', '자체', '작성', 
                                              '장기', '장벽', '장점', '재무', '적극', '적용', '전개', '전년', '전년 동기', 
                                              '전략', '전망', '전문', '전반', '전체', '점유', '제고', '제외', '제품', '조정', '조직', 
                                              '종속', '종합', '주', '주도', '주력', '주식', '주식회사', '주요', '준비', '중심',
                                              '중요', '증가', '증대', '지배', '지분', '지속', '지역', '지원', '지위', '지주',
                                              '지주회사', '진행', '집중', '차별', '차지', '참고', '참여', '참조', '창출',
                                              '채널', '처리', '체계', '체제', '최고', '최근', '최대', '최소', '최초',
                                              '추가', '추세', '추진', '충족', '투자', '특성', '특수', '특징', '평가',
                                              '포함', '필요', '항목', '해당', '해외', '핵심', '향상', '향후', '현재', '현지',
                                              '현황', '형태', '확대', '확보', '확장', '활동', '활용', '회사', '효율'], 
                                  ngram_range=(1,2), max_df = 0.4, min_df = 0.05, lowercase=True, max_features = 550) #0.4 0.05
tfidftransformer = TfidfTransformer()

data = df["morph_sumdart"].copy()
data_trans = tfidftransformer.fit_transform(countvectorizer.fit_transform(data))

# %%
# 실제 학습
clst = KMeans(n_clusters=10, random_state=0)
clst.fit(data_trans)


clusters_text = clst.labels_.tolist()

centers_text = clst.cluster_centers_ # cluster의 중심

# %%
df["cluster"]= clusters_text

df_groupby_cluster = df.groupby('cluster')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df.groupby('cluster')['labels_kse'].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
# Out:
# ['서비스업', '서비스업', '서비스업', '통신업', '서비스업', '서비스업', '전기,전자', '서비스업', '통신업', '통신업', '서비스업', '전기,전자', '서비스업', '서비스업', '서비스업', '화학', '기계']
#
#
# ['금융업', '화학', '철강및금속', '화학', '서비스업', '철강및금속', '화학', '화학', '유통업', '금융업', '금융업', '유통업', '금융업', '유통업', '운수장비', '유통업', '유통업', '운수장비', '화학', '금융업', '기계', '전기,전자', '전기,전자', '금융업', '화학', '서비스업', '금융업', '서비스업', '화학', '유통업', '서비스업', '서비스업', '금융업', '화학', '유통업']
#
#
# ['유통업', '화학', '제조업', '화학', '음식료품', '음식료품', '화학', '유통업', '음식료품', '유통업', '유통업', '유통업', '음식료품', '음식료품', '화학', '섬유,의복', '화학', '음식료품', '유통업', '제조업', '섬유,의복', '금융업', '서비스업', '섬유,의복', '음식료품', '금융업', '음식료품', '음식료품']
#
#
# ['은행', '금융업', '금융업', '보험', '금융업', '보험', '금융업', '은행', '증권', '금융업', '보험', '증권', '금융업', '증권', '증권', '보험', '금융업', '증권', '보험']
#
#
# ['운수장비', '운수장비', '운수장비', '전기,전자', '전기,전자', '화학', '기계', '서비스업', '전기,전자', '화학', '화학', '운수장비', '화학', '운수장비', '전기,전자', '철강및금속', '운수장비', '금융업', '화학']
#
#
# ['서비스업', '운수창고', '운수창고', '운수창고', '운수창고', '운수창고', '운수창고', '유통업', '금융업', '유통업', '운수장비', '운수창고', '철강및금속', '유통업', nan]
#
#
# ['철강및금속', '기계', '건설업', '서비스업', '전기,전자', '전기가스업', '비금속광물', '운수장비', '건설업', '전기,전자', '기계', '건설업', '운수장비', '건설업', '서비스업', '건설업', '건설업', '비금속광물']
#
#
# ['전기,전자', '전기,전자', '화학', '전기,전자', '화학', '금융업', '비금속광물', '화학', '화학', '화학', '전기,전자', '금융업', '화학', '화학', '서비스업', '철강및금속', '화학']
#
#
# ['의약품', '의약품', '의약품', '서비스업', '의약품', '의약품', '의약품', '의약품', '화학', '금융업', '의약품', '의약품', '의약품', '화학', '의약품', '의약품', '의약품', '의약품']
#
#
# ['전기가스업', '운수장비', '전기,전자', '화학', '기계', '화학', '운수장비', '유통업', '제조업', '철강및금속', '유통업', '금융업', '유통업', '기계']

# %%
# 데이터 프레임 형태로 클러스터 결과 확인

df["cluster"]= clusters_text

df_groupby_cluster = df.groupby('cluster')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df.groupby('cluster')['name'].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
# Out:
# ['NAVER', '카카오', '크래프톤', 'SK텔레콤', '엔씨소프트', '하이브', '삼성전기', '넷마블', 'KT', 'LG유플러스', '에스원', '한화시스템', '제일기획', '더블유게임즈', '이노션', '태광산업', 'LIG넥스원']
#
#
# ['LG', 'S-Oil', '고려아연', '한화솔루션', '강원랜드', '현대제철', '금호석유', '한국타이어앤테크놀로지', '이마트', 'GS', '한미사이언스', '호텔신라', '롯데지주', 'GS리테일', '한국항공우주', '롯데쇼핑', '포스코인터내셔널', '현대미포조선', '한화', 'LS', '현대엘리베이', '대한전선', 'LS ELECTRIC', '한국앤컴퍼니', '금호타이어', '롯데관광개발', 'DL', '녹십자홀딩스', '대한유화', 'SK네트웍스', 'CJ CGV', 'GKL', 'SK디스커버리', '넥센타이어', '롯데하이마트']
#
#
# ['삼성물산', 'LG생활건강', 'KT&G;', '아모레퍼시픽', 'CJ제일제당', '오리온', '아모레G', '동서', '하이트진로', '신세계', '휠라홀딩스', '영원무역', '오뚜기', '농심', '동원시스템즈', 'F&F;홀딩스', '코스맥스', '롯데칠성', '신세계인터내셔날', '지누스', '한섬', '오리온홀딩스', '쿠쿠홈시스', '한세실업', '대상', '쿠쿠홀딩스', '동원F&B;', '삼양식품']
#
#
# ['카카오뱅크', 'KB금융', '신한지주', '삼성생명', '하나금융지주', '삼성화재', '우리금융지주', '기업은행', '미래에셋증권', '한국금융지주', 'DB손해보험', '삼성증권', '삼성카드', 'NH투자증권', '메리츠증권', '한화생명', 'BNK금융지주', '키움증권', '현대해상']
#
#
# ['현대차', '기아', '현대모비스', 'LG전자', 'SK아이이테크놀로지', '롯데케미칼', '한온시스템', '코웨이', 'LG이노텍', '효성첨단소재', 'KCC', '만도', '코오롱인더', '현대위아', '세방전지', 'KG동부제철', 'SNT모티브', 'LX홀딩스', 'LX하우시스']
#
#
# ['삼성에스디에스', 'HMM', '대한항공', '현대글로비스', '한진칼', 'CJ대한통운', '팬오션', 'BGF리테일', 'CJ', '한샘', '대우조선해양', '아시아나항공', '동국제강', 'LX인터내셔널', '동원산업']
#
#
# ['POSCO', '두산중공업', '현대건설', '삼성엔지니어링', '일진머티리얼즈', '한국가스공사', '쌍용C&E;', '삼성중공업', 'GS건설', '두산퓨얼셀', '씨에스윈드', '대우건설', '현대로템', 'DL이앤씨', '한전기술', '한전KPS', 'HDC현대산업개발', '아이에스동서']
#
#
# ['삼성전자', 'SK하이닉스', 'LG화학', '삼성SDI', 'SK이노베이션', 'SK', '포스코케미칼', 'SKC', '한솔케미칼', 'OCI', 'DB하이텍', '효성', '롯데정밀화학', '후성', '두산', '영풍', '휴켐스']
#
#
# ['삼성바이오로직스', '셀트리온', 'SK바이오사이언스', 'SK바이오팜', '유한양행', '한미약품', '녹십자', '신풍제약', 'SK케미칼', '대웅', '대웅제약', '종근당', '한올바이오파마', '한국콜마', '보령제약', '부광약품', '영진약품', '일양약품']
#
#
# ['한국전력', '한국조선해양', 'LG디스플레이', '현대중공업지주', '두산밥캣', '효성티앤씨', '한화에어로스페이스', '현대백화점', '화승엔터프라이즈', '풍산', '현대그린푸드', '삼양홀딩스', '현대홈쇼핑', '현대두산인프라코어']

# %% [markdown]
# # 주가변동 : 클러스터 20개

# %%
# 실제 클러스터링
n_clusters = 20
tsclst = TimeSeriesKMeans(n_clusters = n_clusters, metric = 'euclidean') #'euclidean', 'dtw'
tsclst.fit(df_price)

clusters_price = tsclst.labels_.tolist()

centers_price = tsclst.cluster_centers_

# %%
centers_price = centers_price.reshape(n_clusters,248)
centers_price
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-9892d17be6e8> in <module>
# ----> 1 centers_price = centers_price.reshape(n_clusters,248)
#       2 centers_price
#
# ValueError: cannot reshape array of size 14760 into shape (20,248)

# %%
# 데이터 프레임 형태로 클러스터 결과 확인

df_price["cluster"]= clusters_price
df_price["name"]= df_price.index

df_groupby_cluster = df_price.groupby('cluster')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df_price.groupby('cluster')["name"].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
df_price = df_price.drop("name",axis=1, errors = 'ignore')
df_price = df_price.drop("cluster",axis=1, errors = 'ignore')
# Out:
# ['셀트리온', '한화솔루션', '녹십자', '녹십자홀딩스']
#
#
# ['삼성바이오로직스', '두산중공업', '삼성화재', '우리금융지주', '기업은행', '코웨이', '삼성엔지니어링', 'DB손해보험', '삼성증권', '삼성카드', '제일기획', '현대해상', '한전기술', '효성', '대한전선', '한전KPS', '두산', '금호타이어']
#
#
# ['LG', '삼성생명', '아모레퍼시픽', '한국조선해양', '아모레G', '아이에스동서', 'GKL', '동원산업']
#
#
# ['한화', '동원시스템즈']
#
#
# ['신풍제약']
#
#
# ['삼성물산', '한국전력', '한미사이언스', '두산퓨얼셀', '씨에스윈드', 'LS', 'LS ELECTRIC', '대웅제약']
#
#
# ['현대글로비스', 'GS리테일', 'CJ대한통운', '하이트진로', '한국앤컴퍼니', '더블유게임즈', '한국콜마', 'SNT모티브', '현대두산인프라코어', '롯데하이마트']
#
#
# ['POSCO', '현대제철', '한국금융지주', '한화생명', '신세계', '현대백화점', '신세계인터내셔날', 'KG동부제철', 'LX인터내셔널', '화승엔터프라이즈', '한섬', '풍산', '현대그린푸드', '삼양홀딩스', '쿠쿠홀딩스']
#
#
# ['현대차', 'SK이노베이션', 'LG전자', 'SK', 'LG디스플레이', '금호석유', '한국타이어앤테크놀로지', '한국항공우주', 'DB하이텍', 'HDC현대산업개발', '세방전지', '보령제약']
#
#
# ['고려아연', 'SKC', '일진머티리얼즈', '한국가스공사', '한솔케미칼', '메리츠증권', '효성첨단소재', 'KCC', '한샘', '코오롱인더', '롯데정밀화학', '후성', '아시아나항공', 'LIG넥스원']
#
#
# ['삼성전자', 'SK하이닉스', 'LG화학', '현대모비스', '삼성전기', '한온시스템', '오리온', '이마트', '삼성중공업', '만도', '롯데쇼핑', '대한유화']
#
#
# ['NAVER', '삼성SDI', '기아', '포스코케미칼', '대한항공', 'LG이노텍', 'GS건설', 'OCI', '한화시스템', 'BGF리테일', 'CJ', '포스코인터내셔널', '현대로템', '한화에어로스페이스', '현대위아', 'CJ CGV']
#
#
# ['LG생활건강', '엔씨소프트', '삼성에스디에스', '롯데케미칼', '미래에셋증권', '한미약품', '동서', '키움증권', '오뚜기', 'F&F;홀딩스', '부광약품']
#
#
# ['휴켐스']
#
#
# ['넷마블', '롯데지주', '대우조선해양', '휠라홀딩스', '농심', '이노션', '지누스', '현대홈쇼핑', '대상']
#
#
# ['KT&G;', '한진칼']
#
#
# ['KB금융', 'SK텔레콤', '신한지주', '하나금융지주', 'HMM', 'S-Oil', 'KT', 'LG유플러스', '강원랜드', '현대중공업지주', 'GS', '두산밥캣', 'NH투자증권', '호텔신라', 'BNK금융지주', '현대미포조선', '영원무역', '동국제강', '코스맥스', '롯데칠성', '롯데관광개발', '영풍', '태광산업', '오리온홀딩스', '쿠쿠홈시스', '한세실업', '동원F&B;']
#
#
# ['유한양행', '에스원', '대웅']
#
#
# ['카카오', '하이브', 'CJ제일제당', '현대건설', '쌍용C&E;', '팬오션', '대우건설', '효성티앤씨', '현대엘리베이', 'SK네트웍스', '넥센타이어', 'LX하우시스']
#
#
# ['SK바이오팜', 'SK케미칼', 'DL', '종근당', '한올바이오파마', 'SK디스커버리', '영진약품', '삼양식품', '일양약품']

# %%
# 실제 클러스터링
finance_data = df_finance[["PER", "PBR", "PCR", "EV/EBITDA", "Dividend"]]
clst = KMeans(n_clusters=5)
clst.fit(finance_data)

clusters_finance = clst.labels_.tolist()

centers_finance = clst.cluster_centers_

# %%
############## 3번 대안 실행

# %%
df_text_result = df.copy()[['name']]
df_text_result['text_clusters'] = clusters_text

df_text_result
# Out:
#          name  text_clusters
# 0        삼성전자              7
# 1      SK하이닉스              7
# 2       NAVER              0
# 3    삼성바이오로직스              8
# 4        LG화학              7
# ..        ...            ...
# 195     LX홀딩스              4
# 196    롯데하이마트              1
# 197    LX하우시스              4
# 198      삼양식품              2
# 199      일양약품              8
#
# [200 rows x 2 columns]

# %%
df_price_result = pd.DataFrame()
df_price_result['name'] = df_price.index
df_price_result['price_clusters'] = clusters_price
df_price_result
# Out:
#           name  price_clusters
# 0         삼성전자              10
# 1       SK하이닉스              10
# 2        NAVER              11
# 3     삼성바이오로직스               1
# 4         LG화학              10
# ..         ...             ...
# 189  현대두산인프라코어               6
# 190     롯데하이마트               6
# 191     LX하우시스              18
# 192       삼양식품              19
# 193       일양약품              19
#
# [194 rows x 2 columns]

# %%
df_finance_result = pd.DataFrame()
df_finance_result['name'] = df_finance['name']
df_finance_result['finance_clusters'] = clusters_finance
df_finance_result
# Out:
#           name  finance_clusters
# 0         삼성전자                 4
# 1       SK하이닉스                 4
# 2        NAVER                 1
# 3     삼성바이오로직스                 1
# 4         LG화학                 4
# ..         ...               ...
# 193  현대두산인프라코어                 0
# 194     롯데하이마트                 0
# 195     LX하우시스                 0
# 196       삼양식품                 4
# 197       일양약품                 4
#
# [198 rows x 2 columns]

# %%
from scipy.spatial import distance_matrix

# %%
distance_matrix_text = pd.DataFrame(distance_matrix(centers_text, centers_text))
distance_matrix_text
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0
# 14  11.694572  21.104878
# 15  22.050429  14.286283
# 16   5.481347  27.724117
# 17  21.018048  14.905961
# 18   0.000000  27.472856
# 19  27.472856   0.000000

# %%
distance_matrix_finance = pd.DataFrame(distance_matrix(centers_finance, centers_finance))
distance_matrix_finance
# Out:
#           0          1          2          3          4
# 0  0.000000   6.974976   5.083469   9.060419   2.689992
# 1  6.974976   0.000000  10.540177  14.385248   4.706058
# 2  5.083469  10.540177   0.000000   9.551765   6.795907
# 3  9.060419  14.385248   9.551765   0.000000  10.510348
# 4  2.689992   4.706058   6.795907  10.510348   0.000000

# %% [markdown]
# # MIN-Max 정규화 실행시 수행

# %%
# ## 대칭행렬 min_max 정규화하는 함수
# def normalize(distance_matrix):
#     # 행렬 반쪽만 num_list에 추가
#     num_list = []
#     for i in range(len(distance_matrix)):
#         for j in range(i+1, len(distance_matrix)):
#             num_list.append(distance_matrix[i][j])
            
#     num_array = np.array(num_list)
#     max_num = num_array.max() # 평균
#     min_num = num_array.min() # 표준편차
    
    
#     for i in range(len(distance_matrix)):
#         for j in range(len(distance_matrix)):
#             if distance_matrix[i][j] != 0:
#                 distance_matrix[i][j] = (distance_matrix[i][j]-min_num)/(max_num - min_num)
    
#     return distance_matrix

# %%
# distance_matrix_text = normalize(distance_matrix_text)
# distance_matrix_price = normalize(distance_matrix_price)
# distance_matrix_finance = normalize(distance_matrix_finance)

# %% [markdown]
# ---

# %%
# distance_matrix_text

# %%
# distance_matrix_price

# %%
# distance_matrix_finance

# %%
# df_text_result --> 기업개요 클러스터링 결과 200 x 200
# df_price_result --> 주가변동 클러스터링 결과 194 x 194
# df_finance_result --> 재무지표 클러스터링 결과 198 x 198

df_merge_result = pd.merge(df_text_result, df_price_result, left_on='name', right_on='name', how='left')
df_merge_result = pd.merge(df_merge_result, df_finance_result, left_on='name', right_on='name', how='left')
df_merge_result = df_merge_result.fillna(100)
df_merge_result = df_merge_result.astype({'price_clusters':int, 'finance_clusters':int})
df_merge_result
# Out:
#          name  text_clusters  price_clusters  finance_clusters
# 0        삼성전자              7              10                 4
# 1      SK하이닉스              7              10                 4
# 2       NAVER              0              11                 1
# 3    삼성바이오로직스              8               1                 1
# 4        LG화학              7              10                 4
# ..        ...            ...             ...               ...
# 195     LX홀딩스              4             100               100
# 196    롯데하이마트              1               6                 0
# 197    LX하우시스              4              18                 0
# 198      삼양식품              2              19                 4
# 199      일양약품              8              19                 4
#
# [200 rows x 4 columns]

# %%
df_merge_result[df_merge_result['price_clusters'] == 100]
# Out:
#            name  text_clusters  price_clusters  finance_clusters
# 10        카카오뱅크              3             100                 1
# 14         크래프톤              0             100                 1
# 22    SK바이오사이언스              8             100                 1
# 29   SK아이이테크놀로지              4             100                 1
# 115       DL이앤씨              6             100               100
# 195       LX홀딩스              4             100               100

# %%
df_dist_text = pd.DataFrame(index = df_merge_result.index, columns = df_merge_result.index)

# df_clusters_result --> 클러스터링 결과 left join으로 합친 것 200 x 200, null 값은 100으로 채움
# normal_dist_text --> text 클러스터링 distance matrix
# normal_dist_price --> 주가 클러스터링 distance matrix

# 거리의 합으로 새로운 200x200 distance matrix 만들어보자

## 가중치

for i in range(len(df_merge_result)):
    for j in range(len(df_merge_result)):
        distance = 0

        text_cluster_1 = df_merge_result['text_clusters'][i] # 첫 번째 기업의 개요 클러스터
        text_cluster_2 = df_merge_result['text_clusters'][j] # 두 번째 기업의 개요 클러스터
        distance = distance_matrix_text[text_cluster_1][text_cluster_2] # 개요 클러스터 거리 * weight

        
        df_dist_text[i][j] = distance
        

df_dist_text
# Out:
#           0         1         2         3         4         5         6    \
# 0         0.0       0.0   0.60194   0.70555       0.0   0.60194       0.0
# 1         0.0       0.0   0.60194   0.70555       0.0   0.60194       0.0
# 2     0.60194   0.60194       0.0    0.7101   0.60194       0.0   0.60194
# 3     0.70555   0.70555    0.7101       0.0   0.70555    0.7101   0.70555
# 4         0.0       0.0   0.60194   0.70555       0.0   0.60194       0.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.515562  0.515562  0.604808  0.726476  0.515562  0.604808  0.515562
# 196   0.46476   0.46476  0.472188  0.616506   0.46476  0.472188   0.46476
# 197  0.515562  0.515562  0.604808  0.726476  0.515562  0.604808  0.515562
# 198  0.596737  0.596737  0.549876   0.66037  0.596737  0.549876  0.596737
# 199   0.70555   0.70555    0.7101       0.0   0.70555    0.7101   0.70555
#
#           7         8         9    ...       190       191       192  \
# 0    0.515562  0.515562   0.70555  ...  0.596737  0.596737  0.515562
# 1    0.515562  0.515562   0.70555  ...  0.596737  0.596737  0.515562
# 2    0.604808  0.604808    0.7101  ...  0.549876  0.549876  0.604808
# 3    0.726476  0.726476       0.0  ...   0.66037   0.66037  0.726476
# 4    0.515562  0.515562   0.70555  ...  0.596737  0.596737  0.515562
# ..        ...       ...       ...  ...       ...       ...       ...
# 195       0.0       0.0  0.726476  ...  0.569061  0.569061       0.0
# 196  0.453208  0.453208  0.616506  ...   0.42187   0.42187  0.453208
# 197       0.0       0.0  0.726476  ...  0.569061  0.569061       0.0
# 198  0.569061  0.569061   0.66037  ...       0.0       0.0  0.569061
# 199  0.726476  0.726476       0.0  ...   0.66037   0.66037  0.726476
#
#           193       194       195       196       197       198       199
# 0     0.46476   0.59792  0.515562   0.46476  0.515562  0.596737   0.70555
# 1     0.46476   0.59792  0.515562   0.46476  0.515562  0.596737   0.70555
# 2    0.472188  0.590347  0.604808  0.472188  0.604808  0.549876    0.7101
# 3    0.616506  0.719799  0.726476  0.616506  0.726476   0.66037       0.0
# 4     0.46476   0.59792  0.515562   0.46476  0.515562  0.596737   0.70555
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.453208  0.554901       0.0  0.453208       0.0  0.569061  0.726476
# 196       0.0   0.44182  0.453208       0.0  0.453208   0.42187  0.616506
# 197  0.453208  0.554901       0.0  0.453208       0.0  0.569061  0.726476
# 198   0.42187   0.56543  0.569061   0.42187  0.569061       0.0   0.66037
# 199  0.616506  0.719799  0.726476  0.616506  0.726476   0.66037       0.0
#
# [200 rows x 200 columns]

# %%
df_dist_price = pd.DataFrame(index = df_merge_result.index, columns = df_merge_result.index)

# df_clusters_result --> 클러스터링 결과 left join으로 합친 것 200 x 200, null 값은 100으로 채움
# normal_dist_text --> text 클러스터링 distance matrix
# normal_dist_price --> 주가 클러스터링 distance matrix

# 거리의 합으로 새로운 200x200 distance matrix 만들어보자

## 가중치

for i in range(len(df_merge_result)):
    for j in range(len(df_merge_result)):
        distance = 0
        try:
            price_cluster_1 = df_merge_result['price_clusters'][i] # 첫 번째 기업의 개요 클러스터
            price_cluster_2 = df_merge_result['price_clusters'][j] # 두 번째 기업의 개요 클러스터
            distance = distance_matrix_price[price_cluster_1][price_cluster_2] # 개요 클러스터 거리 * weight
        
        except KeyError:
            # 100번 클러스터들 은 그냥 거리를 0으로 지정해 놓는다.
            distance = 0
            
            
        
        df_dist_price[i][j] = distance
        

df_dist_price
# Out:
#            0          1          2          3          4          5    \
# 0          0.0        0.0  12.918459  20.270102        0.0  15.797686
# 1          0.0        0.0  12.918459  20.270102        0.0  15.797686
# 2    12.918459  12.918459        0.0  11.692171  12.918459   6.194932
# 3    20.270102  20.270102  11.692171        0.0  20.270102   8.837265
# 4          0.0        0.0  12.918459  20.270102        0.0  15.797686
# ..         ...        ...        ...        ...        ...        ...
# 195          0          0          0          0          0          0
# 196  10.953953  10.953953  13.837716  17.958169  10.953953  13.160347
# 197  15.797686  15.797686   6.194932   8.837265  15.797686        0.0
# 198  20.700653  20.700653   27.21486  25.950881  20.700653  27.472856
# 199  20.700653  20.700653   27.21486  25.950881  20.700653  27.472856
#
#            6          7          8          9    ...        190        191  \
# 0    12.918459   8.572321  12.918459   13.05501  ...  14.186962  17.711383
# 1    12.918459   8.572321  12.918459   13.05501  ...  14.186962  17.711383
# 2          0.0    6.96298        0.0  21.957579  ...   8.330703   8.617369
# 3    11.692171  16.294799  11.692171  24.976907  ...  12.455564   7.429971
# 4    12.918459   8.572321  12.918459   13.05501  ...  14.186962  17.711383
# ..         ...        ...        ...        ...  ...        ...        ...
# 195          0          0          0          0  ...          0          0
# 196  13.837716  10.024184  13.837716  16.522622  ...  11.885161  14.735602
# 197   6.194932   9.498822   6.194932  23.613543  ...   6.721314   5.481347
# 198   27.21486  25.369427   27.21486  12.013195  ...  27.244954  27.724117
# 199   27.21486  25.369427   27.21486  12.013195  ...  27.244954  27.724117
#
#            192        193        194 195        196        197        198  \
# 0    10.953953  15.797686  10.953953   0  10.953953  15.797686  20.700653
# 1    10.953953  15.797686  10.953953   0  10.953953  15.797686  20.700653
# 2    13.837716   6.194932  13.837716   0  13.837716   6.194932   27.21486
# 3    17.958169   8.837265  17.958169   0  17.958169   8.837265  25.950881
# 4    10.953953  15.797686  10.953953   0  10.953953  15.797686  20.700653
# ..         ...        ...        ...  ..        ...        ...        ...
# 195          0          0          0   0          0          0          0
# 196        0.0  13.160347        0.0   0        0.0  13.160347  20.942156
# 197  13.160347        0.0  13.160347   0  13.160347        0.0  27.472856
# 198  20.942156  27.472856  20.942156   0  20.942156  27.472856        0.0
# 199  20.942156  27.472856  20.942156   0  20.942156  27.472856        0.0
#
#            199
# 0    20.700653
# 1    20.700653
# 2     27.21486
# 3    25.950881
# 4    20.700653
# ..         ...
# 195          0
# 196  20.942156
# 197  27.472856
# 198        0.0
# 199        0.0
#
# [200 rows x 200 columns]

# %%
df_dist_finance = pd.DataFrame(index = df_merge_result.index, columns = df_merge_result.index)

# df_clusters_result --> 클러스터링 결과 left join으로 합친 것 200 x 200, null 값은 100으로 채움
# normal_dist_text --> text 클러스터링 distance matrix
# normal_dist_price --> 주가 클러스터링 distance matrix

# 거리의 합으로 새로운 200x200 distance matrix 만들어보자

## 가중치

for i in range(len(df_merge_result)):
    for j in range(len(df_merge_result)):
        distance = 0
        try:
            finance_cluster_1 = df_merge_result['finance_clusters'][i] # 첫 번째 기업의 개요 클러스터
            finance_cluster_2 = df_merge_result['finance_clusters'][j] # 두 번째 기업의 개요 클러스터
            distance = distance_matrix_finance[finance_cluster_1][finance_cluster_2] # 개요 클러스터 거리 * weight
        except KeyError:
            # 100번 클러스터들 은 그냥 거리를 0으로 지정해 놓는다.
            distance = 0
        
        df_dist_finance[i][j] = distance
        

df_dist_finance
# Out:
#           0         1         2         3         4         5         6    \
# 0         0.0       0.0  4.706058  4.706058       0.0  4.706058       0.0
# 1         0.0       0.0  4.706058  4.706058       0.0  4.706058       0.0
# 2    4.706058  4.706058       0.0       0.0  4.706058       0.0  4.706058
# 3    4.706058  4.706058       0.0       0.0  4.706058       0.0  4.706058
# 4         0.0       0.0  4.706058  4.706058       0.0  4.706058       0.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 195         0         0         0         0         0         0         0
# 196  2.689992  2.689992  6.974976  6.974976  2.689992  6.974976  2.689992
# 197  2.689992  2.689992  6.974976  6.974976  2.689992  6.974976  2.689992
# 198       0.0       0.0  4.706058  4.706058       0.0  4.706058       0.0
# 199       0.0       0.0  4.706058  4.706058       0.0  4.706058       0.0
#
#            7         8         9    ...       190       191       192  \
# 0     6.795907       0.0  4.706058  ...  2.689992  2.689992  2.689992
# 1     6.795907       0.0  4.706058  ...  2.689992  2.689992  2.689992
# 2    10.540177  4.706058       0.0  ...  6.974976  6.974976  6.974976
# 3    10.540177  4.706058       0.0  ...  6.974976  6.974976  6.974976
# 4     6.795907       0.0  4.706058  ...  2.689992  2.689992  2.689992
# ..         ...       ...       ...  ...       ...       ...       ...
# 195          0         0         0  ...         0         0         0
# 196   5.083469  2.689992  6.974976  ...       0.0       0.0       0.0
# 197   5.083469  2.689992  6.974976  ...       0.0       0.0       0.0
# 198   6.795907       0.0  4.706058  ...  2.689992  2.689992  2.689992
# 199   6.795907       0.0  4.706058  ...  2.689992  2.689992  2.689992
#
#           193       194 195       196       197       198       199
# 0    2.689992  2.689992   0  2.689992  2.689992       0.0       0.0
# 1    2.689992  2.689992   0  2.689992  2.689992       0.0       0.0
# 2    6.974976  6.974976   0  6.974976  6.974976  4.706058  4.706058
# 3    6.974976  6.974976   0  6.974976  6.974976  4.706058  4.706058
# 4    2.689992  2.689992   0  2.689992  2.689992       0.0       0.0
# ..        ...       ...  ..       ...       ...       ...       ...
# 195         0         0   0         0         0         0         0
# 196       0.0       0.0   0       0.0       0.0  2.689992  2.689992
# 197       0.0       0.0   0       0.0       0.0  2.689992  2.689992
# 198  2.689992  2.689992   0  2.689992  2.689992       0.0       0.0
# 199  2.689992  2.689992   0  2.689992  2.689992       0.0       0.0
#
# [200 rows x 200 columns]

# %%
text_mean = df_dist_text.sum().sum() / (200 * 199)

# %%
price_mean = df_dist_price.sum().sum() / (194 * 193)

# %%
finance_mean = df_dist_finance.sum().sum() / (198 * 197)

# %%
# 10, 14, 22, 29, (115, 195)
list1 = [10, 14, 22, 29, 115, 195]
list2 = [115, 195]
for i in range(200) :
    for j in range(200):
        if i in list1 or j in list1 :
            df_dist_price.iloc[i,j] = price_mean
        if i in list2 or j in list2 :
            df_dist_finance.iloc[i, j] = finance_mean

# ..        ...       ...       ...       ...       ...       ...       ...
# 195  1.005025  1.005025       0.0  1.005025  1.005025  1.005025  1.005025
# 196  0.959169       0.0  1.005025       0.0  0.959169  1.526332  1.526332
# 197       0.0  0.959169  1.005025  0.959169       0.0  2.002311  2.002311
# 198  2.002311  1.526332  1.005025  1.526332  2.002311       0.0       0.0
# 199  2.002311  1.526332  1.005025  1.526332  2.002311       0.0       0.0
#
# [200 rows x 200 columns]

# %%
ratio_finance = 40000 / df_dist_finance.sum().sum()

df_dist_finance = df_dist_finance * ratio_finance
df_dist_finance
# Out:
#           0         1         2         3         4         5         6    \
# 0         0.0       0.0  1.252256  1.252256       0.0  1.252256       0.0
# 1         0.0       0.0  1.252256  1.252256       0.0  1.252256       0.0
# 2    1.252256  1.252256       0.0       0.0  1.252256       0.0  1.252256
# 3    1.252256  1.252256       0.0       0.0  1.252256       0.0  1.252256
# 4         0.0       0.0  1.252256  1.252256       0.0  1.252256       0.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  1.005025  1.005025  1.005025  1.005025  1.005025  1.005025  1.005025
# 196  0.715792  0.715792  1.856002  1.856002  0.715792  1.856002  0.715792
# 197  0.715792  0.715792  1.856002  1.856002  0.715792  1.856002  0.715792
# 198       0.0       0.0  1.252256  1.252256       0.0  1.252256       0.0
# 199       0.0       0.0  1.252256  1.252256       0.0  1.252256       0.0
#
#           7         8         9    ...       190       191       192  \
# 0    1.808353       0.0  1.252256  ...  0.715792  0.715792  0.715792
# 1    1.808353       0.0  1.252256  ...  0.715792  0.715792  0.715792
# 2    2.804683  1.252256       0.0  ...  1.856002  1.856002  1.856002
# 3    2.804683  1.252256       0.0  ...  1.856002  1.856002  1.856002
# 4    1.808353       0.0  1.252256  ...  0.715792  0.715792  0.715792
# ..        ...       ...       ...  ...       ...       ...       ...
# 195  1.005025  1.005025  1.005025  ...  1.005025  1.005025  1.005025
# 196  1.352683  0.715792  1.856002  ...       0.0       0.0       0.0
# 197  1.352683  0.715792  1.856002  ...       0.0       0.0       0.0
# 198  1.808353       0.0  1.252256  ...  0.715792  0.715792  0.715792
# 199  1.808353       0.0  1.252256  ...  0.715792  0.715792  0.715792
#
#           193       194       195       196       197       198       199
# 0    0.715792  0.715792  1.005025  0.715792  0.715792       0.0       0.0
# 1    0.715792  0.715792  1.005025  0.715792  0.715792       0.0       0.0
# 2    1.856002  1.856002  1.005025  1.856002  1.856002  1.252256  1.252256
# 3    1.856002  1.856002  1.005025  1.856002  1.856002  1.252256  1.252256
# 4    0.715792  0.715792  1.005025  0.715792  0.715792       0.0       0.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  1.005025  1.005025       0.0  1.005025  1.005025  1.005025  1.005025
# 196       0.0       0.0  1.005025       0.0       0.0  0.715792  0.715792
# 197       0.0       0.0  1.005025       0.0       0.0  0.715792  0.715792
# 198  0.715792  0.715792  1.005025  0.715792  0.715792       0.0       0.0
# 199  0.715792  0.715792  1.005025  0.715792  0.715792       0.0       0.0
#
# [200 rows x 200 columns]

# %% [markdown]
# ## 각 센트로이드로 클러스터를 대표시킴

# %% [markdown]
# ## Feature 를 센트로이드로 바꾸는 거랑
# ## 센트로이드들 간의 거리를 다 구해놓고,
# ## 데이터 한개 한개 사이의 거리를 구할 때 클러스터 번호로 찾아가서 구하는거나
# ## 똑같다!

# %%
centers_text = centers_text * ratio_text
centers_text
# Out:
# array([[0.06624966, 0.        , 0.        , ..., 0.01558675, 0.00347223,
#         0.00374893],
#        [0.00767257, 0.0167632 , 0.00919844, ..., 0.01623248, 0.02371436,
#         0.01765344],
#        [0.        , 0.04419889, 0.        , ..., 0.02091049, 0.        ,
#         0.01243231],
#        ...,
#        [0.00684591, 0.00482133, 0.        , ..., 0.00405716, 0.        ,
#         0.00699249],
#        [0.        , 0.0475913 , 0.        , ..., 0.00280802, 0.        ,
#         0.        ],
#        [0.00273113, 0.        , 0.00535398, ..., 0.01343927, 0.01617961,
#         0.01636284]])

# %%
centers_price = centers_price * ratio_price
centers_price
# Out:
# array([[-0.13574715, -0.11691641, -0.12872371, ..., -0.09643336,
#         -0.10015654, -0.10164789],
#        [-0.07994197, -0.07523113, -0.0824866 , ...,  0.10029613,
#          0.10659106,  0.1047486 ],
#        [-0.14425533, -0.14127953, -0.14380428, ..., -0.05257824,
#         -0.05437576, -0.0577789 ],
#        ...,
#        [-0.03631501, -0.03586143, -0.05334901, ..., -0.00816333,
#         -0.00534048, -0.00054931],
#        [-0.11751647, -0.11892065, -0.126249  , ...,  0.00973143,
#          0.00907269,  0.00699332],
#        [ 0.07080342,  0.07046823,  0.05938362, ..., -0.07536267,
#         -0.08077851, -0.08281442]])

# %%
centers_finance = centers_finance * ratio_finance
centers_finance
# Out:
# array([[ 4.55161564e-01, -1.57398282e-01,  4.92281859e-01,
#          7.23062650e-01,  4.55161564e-01],
#        [ 7.34420690e-01,  7.38984683e-01,  1.85507093e+00,
#          1.56180703e+00,  4.04463568e-01],
#        [ 4.58273780e-01, -6.54918133e-02, -7.82592050e-01,
#          1.14145014e+00,  3.10443528e-01],
#        [ 0.00000000e+00,  3.95862617e-01, -5.39548523e-01,
#         -1.28378934e+00,  1.18169675e-16],
#        [ 7.14653673e-01,  2.84869751e-01,  9.25065027e-01,
#          8.95806588e-01,  6.34825337e-01]])

# %%
# cluster 번호를 각 centroid vector로 치환
rows = []
for i in df_merge_result.index:
    try:
        text_cluster = df_merge_result['text_clusters'][i] # 클러스터 번호
        text_center = centers_text[text_cluster] # 센트로이드 벡터
        
    except IndexError: # 인덱싱이 안되면 평균으로
        text_center = centers_text.mean(axis = 0)
        
    try: 
        price_cluster = df_merge_result['price_clusters'][i]
        price_center = centers_price[price_cluster] # 센트로이드 벡터
        
    except IndexError:
        price_center = centers_price.mean(axis = 0)
        # print(price_center)

    try: 
        finance_cluster = df_merge_result['finance_clusters'][i]
        finance_center = centers_finance[finance_cluster] # 센트로이드 벡터
        
    except IndexError:
        finance_center = centers_finance.mean(axis = 0)
        # print(finance_center)
    

    row = np.concatenate((text_center, price_center, finance_center), axis = 0)
    rows.append(row)

# %%
df_result_vectors = pd.DataFrame(rows)
df_result_vectors
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.006846  0.004821  0.000000  0.108243  0.000000  0.010698  0.021751
# 1    0.006846  0.004821  0.000000  0.108243  0.000000  0.010698  0.021751
# 2    0.066250  0.000000  0.000000  0.000000  0.006773  0.010078  0.006397
# 3    0.000000  0.047591  0.000000  0.000000  0.000000  0.000000  0.033204
# 4    0.006846  0.004821  0.000000  0.108243  0.000000  0.010698  0.021751
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.000000  0.010758  0.019165  0.000000  0.000000  0.055924  0.016231
# 196  0.007673  0.016763  0.009198  0.005425  0.045908  0.010834  0.055696
# 197  0.000000  0.010758  0.019165  0.000000  0.000000  0.055924  0.016231
# 198  0.000000  0.044199  0.000000  0.000000  0.008680  0.007991  0.012309
# 199  0.000000  0.047591  0.000000  0.000000  0.000000  0.000000  0.033204
#
#           7         8         9    ...       793       794       795  \
# 0    0.000000  0.110832  0.033076  ... -0.050445 -0.046283 -0.042034
# 1    0.000000  0.110832  0.033076  ... -0.050445 -0.046283 -0.042034
# 2    0.007417  0.013688  0.000000  ...  0.045014  0.046769  0.039441
# 3    0.038498  0.000000  0.000000  ...  0.096595  0.100897  0.100296
# 4    0.000000  0.110832  0.033076  ... -0.050445 -0.046283 -0.042034
# ..        ...       ...       ...  ...       ...       ...       ...
# 195  0.000000  0.008201  0.000000  ... -0.006374 -0.004208 -0.008861
# 196  0.058514  0.047532  0.011505  ... -0.066241 -0.065642 -0.074407
# 197  0.000000  0.008201  0.000000  ...  0.011398  0.013945  0.009731
# 198  0.008383  0.006599  0.000000  ... -0.070871 -0.072374 -0.075363
# 199  0.038498  0.000000  0.000000  ... -0.070871 -0.072374 -0.075363
#
#           796       797       798       799       800       801       802
# 0   -0.047458 -0.044315  0.714654  0.284870  0.925065  0.895807  0.634825
# 1   -0.047458 -0.044315  0.714654  0.284870  0.925065  0.895807  0.634825
# 2    0.038645  0.037182  0.734421  0.738985  1.855071  1.561807  0.404464
# 3    0.106591  0.104749  0.734421  0.738985  1.855071  1.561807  0.404464
# 4   -0.047458 -0.044315  0.714654  0.284870  0.925065  0.895807  0.634825
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -0.009958 -0.012554  0.472502  0.239365  0.390055  0.607667  0.360979
# 196 -0.053273 -0.069639  0.455162 -0.157398  0.492282  0.723063  0.455162
# 197  0.009073  0.006993  0.455162 -0.157398  0.492282  0.723063  0.455162
# 198 -0.080779 -0.082814  0.714654  0.284870  0.925065  0.895807  0.634825
# 199 -0.080779 -0.082814  0.714654  0.284870  0.925065  0.895807  0.634825
#
# [200 rows x 803 columns]

# %%
clst = KMeans(n_clusters = 10)#", metric = 'euclidean', method = 'pam', init = 'k-medoids++', max_iter = 1000"
clst.fit(df_result_vectors)

clusters = clst.labels_.tolist()

centers = clst.cluster_centers_

# %%
# elbow 

clusters_range = list(range(2, 20))
inertia = []

for i in list(range(2, 20)):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_result_vectors)
    inertia.append(kmeans.inertia_)

sns.scatterplot(x=clusters_range, y=inertia)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import silhouette_score

k_range = range(2, 20)
best_n = -1
best_silhouette_score = -1

for k in k_range:
    kmeans = KMeans(n_clusters = k, random_state = 100)
    kmeans.fit(df_result_vectors)
    clusters = kmeans.predict(df_result_vectors)
    
    score = silhouette_score(df_result_vectors, clusters)
    print('k :', k, 'score :', score)
    
    if score > best_silhouette_score:
        best_n = k
        best_silhouette_score = score
        
print('best n :', best_n, 'best score :', best_silhouette_score)
# Out:
# k : 2 score : 0.1722398226532551
# k : 3 score : 0.23209835234924583
# k : 4 score : 0.2480703933130082
# k : 5 score : 0.2105190520770602
# k : 6 score : 0.22657154224821568
# k : 7 score : 0.18897302301072558
# k : 8 score : 0.19071501380589154
# k : 9 score : 0.20420170261466075
# k : 10 score : 0.21588319669139544
# k : 11 score : 0.21663640090130698
# k : 12 score : 0.23166146618667924
# k : 13 score : 0.2167404933610595
# k : 14 score : 0.2702523340534697
# k : 15 score : 0.2718026249457268
# k : 16 score : 0.2795448015859737
# k : 17 score : 0.2804216672520716
# k : 18 score : 0.26587473416324964
# k : 19 score : 0.2858080384149389
# best n : 19 best score : 0.2858080384149389

# %%
# PCA 차원 축소
# %matplotlib inline
using_pca = PCA(n_components=3)
using_pca.fit(df_result_vectors)
pca= using_pca.transform(df_result_vectors)
centers_trans= using_pca.transform(centers)

xs, ys, zs = pca[:, 0], pca[:, 1], pca[:, 2]

df_plot = pd.DataFrame(dict(x=xs, y=ys, z=zs, label=clusters))
groups = df_plot.groupby('label')


fig = plt.figure(figsize=(10, 9))
ax = fig.add_subplot(111, projection = '3d')
ax.margins(0.05)
colors = {0:'r', 1: 'b', 2: 'k', 3: 'm', 4: 'c', 5: 'g', 6: 'w'}
for idx, group in groups:
    ax.plot(group.x, group.y, group.z ,marker='o', linestyle='', ms=5, mec='none')
    ax.set_aspect('auto')
    ax.tick_params(        axis= 'x',
        which='both',
        bottom='off',
        top='off',
        labelbottom='off')
    ax.tick_params(        axis= 'y',
        which='both',
        left='off',
        top='off',
        labelleft='off')
    ax.tick_params(        axis= 'z',
        which='both',
        left='off',
        top='off',
        labelleft='off')



ax.plot(centers_trans[:,0],centers_trans[:,1],centers_trans[:,2], c='b', zorder=100, marker='d', linestyle='')
plt.show()

# %%
#LDA 차원축소
lda = LinearDiscriminantAnalysis(n_components=3)

#학습
lda.fit(df_result_vectors, clusters)
#변형
data_lda = lda.transform(df_result_vectors)
centers_trans= lda.transform(centers)

#DataFrame 생성
lda_columns=['lda_component_1','lda_component_2','lda_component_3']
DF_lda = pd.DataFrame(data_lda, columns=lda_columns)
DF_lda['target']=clusters


#축 지정
xs, ys, zs = data_lda[:, 0], data_lda[:, 1], data_lda[:, 2]

df_plot = pd.DataFrame(dict(x=xs, y=ys, z=zs, label=clusters))
groups = df_plot.groupby('label')

markers=['^', 's', 'o','d','*']
fig = plt.figure(figsize=(10, 9))
ax = fig.add_subplot(111, projection = '3d')
ax.margins(0.05)
colors = {0:'r', 1: 'b', 2: 'k', 3: 'm', 4: 'c', 5: 'g', 6: 'w'}
for idx, group in groups:
    ax.plot(group.x, group.y, group.z ,marker='o', linestyle='', ms=5, mec='none' )
    ax.set_aspect('auto')
    ax.tick_params(        axis= 'x',
        which='both',
        bottom='off',
        top='off',
        labelbottom='off')
    ax.tick_params(        axis= 'y',
        which='both',
        left='off',
        top='off',
        labelleft='off')
    ax.tick_params(        axis= 'z',
        which='both',
        left='off',
        top='off',
        labelleft='off')



ax.plot(centers_trans[:,0],centers_trans[:,1],centers_trans[:,2], c='y', zorder=100, marker='d', linestyle='')
plt.show()

# %%
# 데이터 프레임 형태로 클러스터 결과 확인

df["cluster"]= clusters

df_groupby_cluster = df.groupby('cluster')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df.groupby('cluster')['name'].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
# Out:
# ['SK', 'LG', '현대제철', '금호석유', '한국타이어앤테크놀로지', '이마트', '롯데지주', 'GS리테일', '한국항공우주', '롯데쇼핑', '포스코인터내셔널', '한화', 'LS', '현대엘리베이', 'LS ELECTRIC', '한국앤컴퍼니', '대한유화', '롯데하이마트']
#
#
# ['NAVER', '삼성바이오로직스', '카카오', '카카오뱅크', '크래프톤', '하이브', 'SK아이이테크놀로지', '포스코케미칼', '삼성엔지니어링', '일진머티리얼즈', '한미사이언스', '씨에스윈드', '한전기술', '대한전선', '후성', '지누스']
#
#
# ['SK이노베이션', 'S-Oil', 'SK바이오팜', '강원랜드', '한진칼', '삼성중공업', '롯데관광개발', 'CJ CGV', 'GKL']
#
#
# ['KB금융', '신한지주', '하나금융지주', '기업은행', '한국금융지주', '삼성카드', 'BNK금융지주', '키움증권']
#
#
# ['한미약품', 'SK케미칼', '대웅', '대웅제약', '종근당', '한국콜마', '보령제약', '일양약품']
#
#
# ['아모레퍼시픽', 'CJ제일제당', '아모레G', '하이트진로', '신세계', '휠라홀딩스', '영원무역', '농심', '동원시스템즈', '코스맥스', '롯데칠성', '신세계인터내셔날', '한섬', '오리온홀딩스', '쿠쿠홈시스', '한세실업', '대상', '쿠쿠홀딩스', '동원F&B;']
#
#
# ['셀트리온', 'SK바이오사이언스', '유한양행', '녹십자', '동서', '신풍제약', '한올바이오파마', '부광약품', '영진약품']
#
#
# ['삼성전자', 'SK하이닉스', 'LG화학', '삼성물산', '엔씨소프트', '삼성전기', '미래에셋증권', '오리온', '에스원', 'DB하이텍']
#
#
# ['한국전력', 'LG디스플레이', '현대중공업지주', '두산밥캣', '효성티앤씨', '한화에어로스페이스', '현대백화점', '화승엔터프라이즈', '풍산', '현대그린푸드', '삼양홀딩스', '현대홈쇼핑', '현대두산인프라코어']
#
#
# ['HMM', '대한항공', '현대글로비스', 'CJ대한통운', '팬오션', 'BGF리테일', 'CJ', '한샘', '동국제강', 'LX인터내셔널', '동원산업']
#
#
# ['삼성생명', '삼성화재', '우리금융지주', 'DB손해보험', '삼성증권', 'NH투자증권', '메리츠증권', '한화생명', '현대해상']
#
#
# ['POSCO', '두산중공업', '현대건설', '한국가스공사', '쌍용C&E;', 'GS건설', '대우건설', '현대로템', 'DL이앤씨', '한전KPS']
#
#
# ['현대차', '한국조선해양', '호텔신라', '두산퓨얼셀', 'OCI', '대우조선해양', '아시아나항공', 'HDC현대산업개발', '아이에스동서', 'SK네트웍스']
#
#
# ['GS', '현대미포조선', '효성', '금호타이어', '영풍', '넥센타이어']
#
#
# ['코웨이', '효성첨단소재', 'KCC', '코오롱인더', 'LX하우시스']
#
#
# ['LG생활건강', '삼성에스디에스', 'KT&G;', '한화솔루션', '롯데케미칼', '오뚜기', 'F&F;홀딩스', 'DL', '녹십자홀딩스', 'SK디스커버리', '삼양식품']
#
#
# ['삼성SDI', '고려아연', 'SKC', '한솔케미칼', '롯데정밀화학', '두산', '휴켐스']
#
#
# ['SK텔레콤', '넷마블', 'KT', 'LG유플러스', '한화시스템', '제일기획', '더블유게임즈', '이노션', '태광산업', 'LIG넥스원']
#
#
# ['기아', '현대모비스', 'LG전자', '한온시스템', 'LG이노텍', '만도', '현대위아', '세방전지', 'KG동부제철', 'SNT모티브', 'LX홀딩스']

# %%
# 데이터 프레임 형태로 클러스터 결과 확인

df["cluster"]= clusters

df_groupby_cluster = df.groupby('cluster')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df.groupby('cluster')['labels_kse'].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
# Out:
# ['금융업', '금융업', '철강및금속', '화학', '화학', '유통업', '금융업', '유통업', '운수장비', '유통업', '유통업', '화학', '금융업', '기계', '전기,전자', '금융업', '화학', '유통업']
#
#
# ['서비스업', '의약품', '서비스업', '은행', '서비스업', '서비스업', '전기,전자', '비금속광물', '서비스업', '전기,전자', '금융업', '기계', '서비스업', '전기,전자', '화학', '제조업']
#
#
# ['화학', '화학', '서비스업', '서비스업', '운수창고', '운수장비', '서비스업', '서비스업', '서비스업']
#
#
# ['금융업', '금융업', '금융업', '은행', '금융업', '금융업', '금융업', '증권']
#
#
# ['의약품', '화학', '금융업', '의약품', '의약품', '화학', '의약품', '의약품']
#
#
# ['화학', '음식료품', '화학', '음식료품', '유통업', '유통업', '유통업', '음식료품', '화학', '화학', '음식료품', '유통업', '섬유,의복', '금융업', '서비스업', '섬유,의복', '음식료품', '금융업', '음식료품']
#
#
# ['의약품', '의약품', '의약품', '의약품', '유통업', '의약품', '의약품', '의약품', '의약품']
#
#
# ['전기,전자', '전기,전자', '화학', '유통업', '서비스업', '전기,전자', '증권', '음식료품', '서비스업', '전기,전자']
#
#
# ['전기가스업', '전기,전자', '화학', '기계', '화학', '운수장비', '유통업', '제조업', '철강및금속', '유통업', '금융업', '유통업', '기계']
#
#
# ['운수창고', '운수창고', '운수창고', '운수창고', '운수창고', '유통업', '금융업', '유통업', '철강및금속', '유통업', nan]
#
#
# ['보험', '보험', '금융업', '보험', '증권', '증권', '증권', '보험', '보험']
#
#
# ['철강및금속', '기계', '건설업', '전기가스업', '비금속광물', '건설업', '건설업', '운수장비', '건설업', '건설업']
#
#
# ['운수장비', '운수장비', '유통업', '전기,전자', '화학', '운수장비', '운수창고', '건설업', '비금속광물', '유통업']
#
#
# ['금융업', '운수장비', '금융업', '화학', '철강및금속', '화학']
#
#
# ['서비스업', '화학', '화학', '화학', '화학']
#
#
# ['화학', '서비스업', '제조업', '화학', '화학', '음식료품', '섬유,의복', '금융업', '서비스업', '금융업', '음식료품']
#
#
# ['전기,전자', '철강및금속', '화학', '화학', '화학', '서비스업', '화학']
#
#
# 197  16.475154  17.669114
# 198        0.0   5.008786
# 199   5.008786        0.0
#
# [200 rows x 200 columns]

# %%
from sklearn_extra.cluster import KMedoids
kmedoids = KMedoids(n_clusters = 10, metric = 'precomputed', method = 'pam', init = 'k-medoids++', max_iter = 10000)

# %%
kmedoids.fit(df_dist_new)
# Out:
# KMedoids(init='k-medoids++', max_iter=10000, method='pam', metric='precomputed',
#          n_clusters=10)

# %%
# elbow 

clusters_range = list(range(2, 20))
inertia = []

for i in list(range(2, 20)):
    kmeans = KMedoids(n_clusters = i, metric = 'precomputed', method = 'pam', init = 'k-medoids++', max_iter = 300)
    kmeans.fit(df_dist_new)
    inertia.append(kmeans.inertia_)

sns.scatterplot(x=clusters_range, y=inertia)
# Out:
# <AxesSubplot:>

# %%
kmedoids_clusters = kmedoids.labels_
kmedoids_clusters
# Out:
# array([8, 8, 3, 5, 8, 5, 8, 3, 3, 6, 5, 1, 3, 7, 5, 0, 9, 2, 9, 7, 3, 4,
#        6, 4, 1, 4, 7, 9, 5, 3, 9, 2, 5, 9, 7, 0, 8, 2, 4, 9, 8, 3, 7, 7,
#        2, 4, 9, 3, 6, 1, 8, 2, 4, 1, 0, 3, 2, 1, 2, 9, 4, 4, 5, 9, 1, 7,
#        5, 7, 3, 4, 6, 7, 9, 2, 7, 8, 5, 8, 3, 1, 0, 0, 7, 3, 7, 4, 4, 4,
#        7, 7, 9, 3, 8, 3, 9, 6, 3, 3, 9, 6, 4, 1, 3, 7, 3, 4, 5, 3, 7, 8,
#        4, 2, 8, 1, 3, 5, 2, 7, 9, 4, 5, 7, 2, 3, 8, 1, 9, 3, 8, 6, 8, 4,
#        2, 3, 5, 5, 1, 6, 8, 4, 9, 2, 7, 7, 2, 9, 4, 3, 2, 8, 2, 2, 2, 0,
#        4, 7, 9, 6, 4, 2, 7, 2, 4, 4, 2, 3, 0, 9, 3, 1, 6, 1, 2, 4, 8, 2,
#        0, 8, 2, 3, 2, 6, 1, 1, 4, 1, 6, 1, 4, 2, 2, 2, 4, 4, 4, 3, 4, 3,
#        9, 6], dtype=int64)

# %%
kmedoids_med = kmedoids.medoid_indices_
kmedoids_med
# Out:
# array([ 54, 136, 132,   8,  86,  62, 170, 103,  50,  18])

# %%
# 데이터 프레임 형태로 클러스터 결과 확인
df_merge_result["merge_clusters"]= kmedoids_clusters

df_groupby_cluster = df_merge_result.groupby('merge_clusters')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df_merge_result.groupby('merge_clusters')['name'].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
# Out:
# ['SK이노베이션', 'S-Oil', '강원랜드', '한진칼', '삼성중공업', '롯데관광개발', 'CJ CGV', 'GKL']
#
#
# ['POSCO', '한국전력', '한국조선해양', 'LG디스플레이', '현대제철', '현대중공업지주', '두산밥캣', '한화생명', '효성티앤씨', '한화에어로스페이스', '현대백화점', 'LX인터내셔널', '화승엔터프라이즈', '풍산', '현대그린푸드', '삼양홀딩스', '현대홈쇼핑']
#
#
# ['SK텔레콤', 'HMM', 'KT&G;', 'KT', 'LG유플러스', 'CJ제일제당', '현대건설', 'GS', '대우건설', '현대미포조선', '신세계', '영원무역', '농심', '동원시스템즈', '동국제강', '금호타이어', '코스맥스', '롯데칠성', '영풍', '신세계인터내셔날', '태광산업', '한섬', '오리온홀딩스', '쿠쿠홈시스', '한세실업', '대상', '쿠쿠홀딩스', '동원F&B;']
#
#
# ['NAVER', '현대차', '기아', '현대모비스', 'LG전자', 'SK아이이테크놀로지', '대한항공', '한온시스템', '코웨이', 'LG이노텍', '쌍용C&E;', 'GS건설', '팬오션', '효성첨단소재', '한화시스템', 'KCC', 'BGF리테일', '만도', 'CJ', '현대로템', '코오롱인더', '현대위아', '현대엘리베이', '대웅제약', '세방전지', 'KG동부제철', '보령제약', 'LX홀딩스', 'LX하우시스']
#
#
# ['SK', 'LG', '삼성생명', '넷마블', '한화솔루션', '현대글로비스', '금호석유', '한국타이어앤테크놀로지', '이마트', '롯데지주', 'GS리테일', 'CJ대한통운', '한국항공우주', '롯데쇼핑', '포스코인터내셔널', '한화', 'LS', 'LS ELECTRIC', '한국앤컴퍼니', 'DL', '대한유화', '더블유게임즈', '이노션', '한국콜마', 'SK디스커버리', '동원산업', 'SNT모티브', '넥센타이어', '현대두산인프라코어', '롯데하이마트']
#
#
# ['삼성바이오로직스', '카카오', '카카오뱅크', '크래프톤', '하이브', '두산중공업', '삼성엔지니어링', '일진머티리얼즈', '한미사이언스', '씨에스윈드', 'DL이앤씨', '한전기술', '대한전선', '한전KPS']
#
#
# ['셀트리온', 'SK바이오사이언스', 'SK바이오팜', '유한양행', '녹십자', '신풍제약', 'SK케미칼', '대웅', '종근당', '한올바이오파마', '부광약품', '영진약품', '일양약품']
#
#
# ['KB금융', '신한지주', '하나금융지주', '삼성화재', '우리금융지주', '기업은행', '한국금융지주', 'DB손해보험', '삼성증권', '삼성카드', 'NH투자증권', '호텔신라', '메리츠증권', '두산퓨얼셀', 'BNK금융지주', '키움증권', '현대해상', '대우조선해양', '아시아나항공', 'HDC현대산업개발', '아이에스동서', 'SK네트웍스']
#
#
# ['삼성전자', 'SK하이닉스', 'LG화학', '삼성SDI', '포스코케미칼', '고려아연', 'SKC', '한국가스공사', '한솔케미칼', 'OCI', '제일기획', '한샘', 'DB하이텍', '효성', '롯데정밀화학', '후성', '두산', '휴켐스', 'LIG넥스원']
#
#
# ['삼성물산', 'LG생활건강', '엔씨소프트', '삼성에스디에스', '삼성전기', '아모레퍼시픽', '롯데케미칼', '미래에셋증권', '오리온', '아모레G', '한미약품', '에스원', '동서', '하이트진로', '휠라홀딩스', '오뚜기', 'F&F;홀딩스', '녹십자홀딩스', '지누스', '삼양식품']

# %%
# 데이터 프레임 형태로 클러스터 결과 확인
df_join = pd.merge(df, df_merge_result[['name', 'merge_clusters']], left_on='name', right_on='name', how='inner')

df_groupby_cluster = df_join.groupby('merge_clusters')
#result = dict(list((df_groupby_cluster['name'])))

groupby_list = df_join.groupby('merge_clusters')['labels_kse'].apply(list)

for i in groupby_list:
    print(i)
    print('\n')
# Out:
# ['화학', '화학', '서비스업', '운수창고', '운수장비', '서비스업', '서비스업', '서비스업']
#
#
# ['철강및금속', '전기가스업', '운수장비', '전기,전자', '철강및금속', '화학', '기계', '보험', '화학', '운수장비', '유통업', '유통업', '제조업', '철강및금속', '유통업', '금융업', '유통업']
#
#
# ['통신업', '운수창고', '제조업', '통신업', '통신업', '음식료품', '건설업', '금융업', '건설업', '운수장비', '유통업', '유통업', '음식료품', '화학', '철강및금속', '화학', '화학', '음식료품', '철강및금속', '유통업', '화학', '섬유,의복', '금융업', '서비스업', '섬유,의복', '음식료품', '금융업', '음식료품']
#
#
# ['서비스업', '운수장비', '운수장비', '운수장비', '전기,전자', '전기,전자', '운수창고', '기계', '서비스업', '전기,전자', '비금속광물', '건설업', '운수창고', '화학', '전기,전자', '화학', '유통업', '운수장비', '금융업', '운수장비', '화학', '운수장비', '기계', '의약품', '전기,전자', '철강및금속', '의약품', '금융업', '화학']
#
#
# ['금융업', '금융업', '보험', '서비스업', '화학', '운수창고', '화학', '화학', '유통업', '금융업', '유통업', '운수창고', '운수장비', '유통업', '유통업', '화학', '금융업', '전기,전자', '금융업', '금융업', '화학', '서비스업', '서비스업', '화학', '금융업', nan, '운수장비', '화학', '기계', '유통업']
#
#
# ['의약품', '서비스업', '은행', '서비스업', '서비스업', '기계', '서비스업', '전기,전자', '금융업', '기계', '건설업', '서비스업', '전기,전자', '건설업']
#
#
# ['의약품', '의약품', '서비스업', '의약품', '의약품', '의약품', '화학', '금융업', '의약품', '의약품', '의약품', '의약품', '의약품']
#
#
# ['금융업', '금융업', '금융업', '보험', '금융업', '은행', '금융업', '보험', '증권', '금융업', '증권', '유통업', '증권', '전기,전자', '금융업', '증권', '보험', '운수장비', '운수창고', '건설업', '비금속광물', '유통업']
#
#
# ['전기,전자', '전기,전자', '화학', '전기,전자', '비금속광물', '철강및금속', '화학', '전기가스업', '화학', '화학', '서비스업', '유통업', '전기,전자', '금융업', '화학', '화학', '서비스업', '화학', '기계']
#
#
# ['유통업', '화학', '서비스업', '서비스업', '전기,전자', '화학', '화학', '증권', '음식료품', '화학', '의약품', '서비스업', '유통업', '음식료품', '유통업', '음식료품', '섬유,의복', '서비스업', '제조업', '음식료품']

# %%
df_merge_result.loc[kmedoids_med]
# Out:
#         name  text_clusters  price_clusters  finance_clusters  merge_clusters
# 54      강원랜드              1              16                 3               0
# 136    현대백화점              9               7                 0               1
# 132     영원무역              2              16                 0               2
# 8         기아              4              11                 4               3
# 86     GS리테일              1               6                 0               4
# 62   삼성엔지니어링              6               1                 1               5
# 170  한올바이오파마              8              19                 1               6
# 103  BNK금융지주              3              16                 2               7
# 50       SKC              7               9                 4               8
# 18    LG생활건강              2              12                 4               9

# %%
df_merge_result
# Out:
#          name  text_clusters  price_clusters  finance_clusters  merge_clusters
# 0        삼성전자              7              10                 4               8
# 1      SK하이닉스              7              10                 4               8
# 2       NAVER              0              11                 1               3
# 3    삼성바이오로직스              8               1                 1               5
# 4        LG화학              7              10                 4               8
# ..        ...            ...             ...               ...             ...
# 195     LX홀딩스              4             100               100               3
# 196    롯데하이마트              1               6                 0               4
# 197    LX하우시스              4              18                 0               3
# 198      삼양식품              2              19                 4               9
# 199      일양약품              8              19                 4               6
#
# [200 rows x 5 columns]

# %%
df_origin_price = pd.read_pickle('../fkl/price-2024.fkl')
df_origin_price = df_origin_price.transpose().copy()
df_origin_price
# Out:
# Date      2021-04-01  2021-04-02  2021-04-05  2021-04-06   2021-04-07  \
# 삼성전자       82900.000   84800.000   85400.000   86000.000   85600.0000
# SK하이닉스    140500.000  141000.000  143000.000  143000.000  143500.0000
# LG에너지솔루션         NaN         NaN         NaN         NaN          NaN
# 현대차       219000.000  233500.000  234000.000  230000.000  230000.0000
# 삼성바이오로직스  739153.875  736185.375  742122.375  746080.375  756964.8125
# ...              ...         ...         ...         ...          ...
# 롯데관광개발     19500.000   19300.000   19050.000   19950.000   19950.0000
# 신풍제약       82900.000   81300.000   85300.000   84200.000   85900.0000
# KG스틸       14550.000   14150.000   14600.000   14400.000   15800.0000
# 영풍        582000.000  581000.000  588000.000  591000.000  589000.0000
# 녹십자홀딩스     34700.000   34400.000   33750.000   32550.000   32950.0000
#
# Date       2021-04-08   2021-04-09  2021-04-12  2021-04-13  2021-04-14  ...  \
# 삼성전자       84700.0000   83600.0000    83200.00    84000.00    84000.00  ...
# SK하이닉스    144000.0000  140000.0000   137500.00   139500.00   137000.00  ...
# LG에너지솔루션          NaN          NaN         NaN         NaN         NaN  ...
# 현대차       231500.0000  228500.0000   226000.00   230000.00   232500.00  ...
# 삼성바이오로직스  754985.8125  761912.3125   773786.25   775765.25   781702.25  ...
# ...               ...          ...         ...         ...         ...  ...
# 롯데관광개발     19500.0000   19300.0000    18900.00    18900.00    18950.00  ...
# 신풍제약       88900.0000   89100.0000    90800.00    90100.00    90000.00  ...
# KG스틸       16100.0000   15600.0000    15700.00    15250.00    14900.00  ...
# 영풍        589000.0000  589000.0000   606000.00   603000.00   612000.00  ...
# 녹십자홀딩스     33100.0000   35750.0000    37200.00    38000.00    37850.00  ...
#
# Date      2024-03-18  2024-03-19  2024-03-20  2024-03-21  2024-03-22  \
# 삼성전자         72800.0     72800.0     76900.0     79300.0     78900.0
# SK하이닉스      164300.0    160200.0    156500.0    170000.0    169800.0
# LG에너지솔루션    407500.0    403000.0    407500.0    413500.0    413500.0
# 현대차         242500.0    237500.0    241000.0    252000.0    243500.0
# 삼성바이오로직스    859000.0    848000.0    850000.0    857000.0    840000.0
# ...              ...         ...         ...         ...         ...
# 롯데관광개발        9030.0      9140.0      8970.0      9020.0      9190.0
# 신풍제약         11740.0     11810.0     12770.0     12670.0     16260.0
# KG스틸          7200.0      7040.0      7000.0      7070.0      7090.0
# 영풍          470500.0    468000.0    466500.0    481500.0    483000.0
# 녹십자홀딩스       16770.0     16680.0     17140.0     17470.0     17700.0
#
# Date      2024-03-25  2024-03-26  2024-03-27  2024-03-28  2024-03-29
# 삼성전자         78200.0     79900.0     79800.0     80800.0     82400.0
# SK하이닉스      169400.0    176600.0    181200.0    178200.0    183000.0
# LG에너지솔루션    414500.0    406000.0    409000.0    401500.0    395000.0
# 현대차         239500.0    240500.0    244000.0    237000.0    233000.0
# 삼성바이오로직스    840000.0    828000.0    836000.0    833000.0    831000.0
# ...              ...         ...         ...         ...         ...
# 롯데관광개발        9150.0      9450.0      9990.0      9750.0      9790.0
# 신풍제약         18320.0     16820.0     16150.0     15820.0     15510.0
# KG스틸          7000.0      7150.0      7150.0      7020.0      7000.0
# 영풍          475000.0    476500.0    479500.0    477000.0    472000.0
# 녹십자홀딩스       17790.0     17800.0     17680.0     17350.0     17190.0
#
# [200 rows x 738 columns]

# %%
# 10개의 클러스터 (0~9) 로 나뉘었음

portfolio = [5,1,2]
sum_profit = 0


for idx in range(0,200):
    if (df_merge_result.iloc[idx]["merge_clusters"] in portfolio):
        start = 0
        for i in range(0,200):
            if (not pd.isna(df_origin_price.iloc[idx][i])) :
                start = df_origin_price.iloc[idx][i]
                break
        print(df_merge_result.iloc[idx]["name"])
        print(start)
        print(df_origin_price.iloc[idx][-1])
        
        sum_profit += df_origin_price.iloc[idx][-1] - start
        print(sum_profit)
        print('--------------------------------')
# Out:
# 삼성바이오로직스
# 219000.0
# 233000.0
# 14000.0
# --------------------------------
# 카카오
# 83500.0
# 110200.0
# 40700.0
# --------------------------------
# 카카오뱅크
# 667000.0
# 471000.0
# -155300.0
# --------------------------------
# POSCO
# 819000.0
# 439000.0
# -535300.0
# --------------------------------
# 크래프톤
# 155500.0
# 303500.0
# -387300.0
# --------------------------------
# SK텔레콤
# 41350.0
# 57700.0
# -370950.0
# --------------------------------
# 한국전력
# 23500.0
# 22000.0
# -372450.0
# --------------------------------
# 하이브
# 12140.732421875
# 17220.0
# -367370.732421875
# --------------------------------
# HMM
# 81400.0
# 93500.0
# -355270.732421875
# --------------------------------
# 두산중공업
# 192000.0
# 148700.0
# -398570.732421875
# --------------------------------
# KT&G;
# 10050.0
# 14320.0
# -394300.732421875
# --------------------------------
# KT
# 23813.50390625
# 27600.0
# -390514.236328125
# --------------------------------
# 한국조선해양
# 27200.0
# 21700.0
# -396014.236328125
# --------------------------------
# LG유플러스
# 47200.0
# 94700.0
# -348514.236328125
# --------------------------------
# LG디스플레이
# 104500.0
# 91700.0
# -361314.236328125
# --------------------------------
# CJ제일제당
# 7400.0
# 48900.0
# -319814.236328125
# --------------------------------
# 현대제철
# 209000.0
# 196700.0
# -332114.236328125
# --------------------------------
# 현대건설
# 133500.0
# 111200.0
# -354414.236328125
# --------------------------------
# 삼성엔지니어링
# 56600.0
# 71900.0
# -339114.236328125
# --------------------------------
# 현대중공업지주
# 4340.0
# 115600.0
# -227854.236328125
# --------------------------------
# 일진머티리얼즈
# 21050.34765625
# 10750.0
# -238154.583984375
# --------------------------------
# GS
# 13900.0
# 25000.0
# -227054.583984375
# --------------------------------
# 한미사이언스
# 875000.0
# 198800.0
# -903254.583984375
# --------------------------------
# 두산밥캣
# 19900.0
# 36800.0
# -886354.583984375
# --------------------------------
# 한화생명
# 9489.966796875
# 10410.0
# -885434.55078125
# --------------------------------
# 씨에스윈드
# 18200.0
# 5870.0
# -897764.55078125
# --------------------------------
# 대우건설
# 23000.0
# 65200.0
# -855564.55078125
# --------------------------------
# 효성티앤씨
# 42150.0
# 38050.0
# -859664.55078125
# --------------------------------
# DL이앤씨
# 180500.0
# 114900.0
# -925264.55078125
# --------------------------------
# 현대미포조선
# 38250.0
# 20300.0
# -943214.55078125
# --------------------------------
# 한전기술
# 55940.0234375
# 38300.0
# -960854.57421875
# --------------------------------
# 신세계
# 21000.0
# 18780.0
# -963074.57421875
# --------------------------------
# 한화에어로스페이스
# 3805.0
# 5890.0
# -960989.57421875
# --------------------------------
# 영원무역
# 118891.2265625
# 120100.0
# -959780.80078125
# --------------------------------
# 대한전선
# 23550.0
# 37400.0
# -945930.80078125
# --------------------------------
# 한전KPS
# 22300.0
# 31200.0
# -937030.80078125
# --------------------------------
# 현대백화점
# 168500.0
# 67700.0
# -1037830.80078125
# --------------------------------
# 농심
# 558000.0
# 324500.0
# -1271330.80078125
# --------------------------------
# 동원시스템즈
# 77600.0
# 56700.0
# -1292230.80078125
# --------------------------------
# 동국제강
# 57100.0
# 46600.0
# -1302730.80078125
# --------------------------------
# 금호타이어
# 51500.0
# 20500.0
# -1333730.80078125
# --------------------------------
# 코스맥스
# 18200.0
# 15990.0
# -1335940.80078125
# --------------------------------
# 롯데칠성
# 4695.0
# 59400.0
# -1281235.80078125
# --------------------------------
# 영풍
# 49385.82421875
# 43000.0
# -1287621.625
# --------------------------------
# 신세계인터내셔날
# 41700.0
# 14950.0
# -1314371.625
# --------------------------------
# 태광산업
# 61000.0
# 11800.0
# -1363571.625
# --------------------------------
# LX인터내셔널
# 134000.0
# 127100.0
# -1370471.625
# --------------------------------
# 화승엔터프라이즈
# 31100.0
# 27000.0
# -1374571.625
# --------------------------------
# 한섬
# 43400.0
# 86900.0
# -1331071.625
# --------------------------------
# 오리온홀딩스
# 8498.6162109375
# 6470.0
# -1333100.2412109375
# --------------------------------
# 쿠쿠홈시스
# 56250.0
# 41350.0
# -1348000.2412109375
# --------------------------------
# 한세실업
# 16200.0
# 12300.0
# -1351900.2412109375
# --------------------------------
# 풍산
# 14450.0
# 14000.0
# -1352350.2412109375
# --------------------------------
# 현대그린푸드
# 171000.0
# 62300.0
# -1461050.2412109375
# --------------------------------
# 삼양홀딩스
# 20000.0
# 19990.0
# -1461060.2412109375
# --------------------------------
# 현대홈쇼핑
# 46550.0
# 21850.0
# -1485760.2412109375
# --------------------------------
# 대상
# 15050.0
# 11050.0
# -1489760.2412109375
# --------------------------------
# 쿠쿠홀딩스
# 10550.0
# 8000.0
# -1492310.2412109375
# --------------------------------
# 동원F&B;
# 18950.0
# 22800.0
# -1488460.2412109375
# --------------------------------

# %%
sum_profit
# Out:
# -1488460.2412109375
